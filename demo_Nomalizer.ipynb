# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## NORMALIZER

# %%
# định cỡ lại để độ dài (khoảng cách từ các điểm đến trung tâm đều có giá trị là 1)
# giả sử có 3 tính năng là x, y z ==> công thức của Normalizer
# xi / sqrt(xi2 + yi2 + zi2)

# %%
df = pd.DataFrame({
    'A': np.random.randint(-100, 100, 1000).astype(float),
    'B': np.random.randint(-80, 80, 1000).astype(float),
    'C': np.random.randint(-150, 150, 1000).astype(float)
})
df.head()
# Out:
#       A     B      C
# 0 -73.0  77.0   27.0
# 1  93.0  79.0    1.0
# 2  77.0 -10.0  120.0
# 3 -78.0  58.0  -98.0
# 4 -66.0 -46.0   25.0

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
f = plt.figure(figsize=(6,6))
ax = f.add_subplot(111, projection='3d')
ax.scatter(df['A'], df['B'], df['C'])
plt.show()

# %%
from sklearn.preprocessing import Normalizer

# %%
scaler = Normalizer()

# %%
df_scale = scaler.fit_transform(df)
df_scale = pd.DataFrame(df_scale, columns=df.columns)
df_scale.head()
# Out:
#           A         B         C
# 0 -0.666757  0.703292  0.246609
# 1  0.762116  0.647389  0.008195
# 2  0.538725 -0.069964  0.839572
# 3 -0.565099  0.420202 -0.709996
# 4 -0.783441 -0.546035  0.296758

# %%
f = plt.figure(figsize=(6,6))
ax = f.add_subplot(111, projection='3d')
ax.scatter(df_scale['A'], df_scale['B'], df_scale['C'])
plt.show()
